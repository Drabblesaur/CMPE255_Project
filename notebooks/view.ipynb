# %%
import os
os.chdir("/home/017534556/projects/255_final")

# %%
import pandas as pd

# %%
df = pd.read_csv("Training.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                                              title  \
# 0        6910  Thanksgiving in the Time of COVID-19, High Inf...
# 1         172  Perspectives: West Coast Wildfires and Climate...
# 2        8476  Biden, Bipartisan Senators Reach Agreement on ...
# 3        1440               MittÃ¢â‚¬â„¢s View on Foreign Policy
# 4       15716  US, Taiwan Agree to Talks on New Trade Deal Am...
#
#                                                 tags  \
# 0  ['Holidays', 'Thanksgiving', 'Coronavirus', 'I...
# 1  ['Environment', 'California', 'Oregon', 'Clima...
# 2  ['Economic Policy', 'Economy And Jobs', 'Bipar...
# 3            ['Presidential Elections', 'Elections']
# 4  ['Trade', 'China', 'Taiwan', 'Foreign Policy',...
#
#                                              heading                source  \
# 0  Turkey farmers explain why prices are so high ...             Fox News
# 1  Wild weather this year shows growing impact of...               Reuters
# ...

# %%
# do a grouping of source and counting bias_rating, like Fox News, left : count, right : count, center : count 
df.groupby(['source', 'bias_rating']).size().unstack().plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='source'>
